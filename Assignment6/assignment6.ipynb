# %%
# %pip install --upgrade google-genai pillow
# Out:
# Collecting google-genai
#   Downloading google_genai-1.66.0-py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: pillow in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (10.3.0)
# Collecting pillow
#   Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (4.9.0)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading google_auth-2.49.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (14.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (4.12.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.0)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (44.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (4.9)
# Requirement already satisfied: certifi in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.2.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.0)
# Requirement already satisfied: pycparser in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.22)
# Downloading google_genai-1.66.0-py3-none-any.whl (732 kB)
#    ---------------------------------------- 0.0/732.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/732.2 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/732.2 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/732.2 kB ? eta -:--:--
#    --------------------------- ---------- 524.3/732.2 kB 621.2 kB/s eta 0:00:01
#    --------------------------- ---------- 524.3/732.2 kB 621.2 kB/s eta 0:00:01
#    -------------------------------------- 732.2/732.2 kB 626.7 kB/s eta 0:00:00
# Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 621.2 kB/s eta 0:00:11
#    -- ------------------------------------- 0.5/7.0 MB 621.2 kB/s eta 0:00:11
#    ---- ----------------------------------- 0.8/7.0 MB 621.2 kB/s eta 0:00:11
#    ---- ----------------------------------- 0.8/7.0 MB 621.2 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.0/7.0 MB 613.9 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.0/7.0 MB 613.9 kB/s eta 0:00:10
#    ------- -------------------------------- 1.3/7.0 MB 615.7 kB/s eta 0:00:10
#    ------- -------------------------------- 1.3/7.0 MB 615.7 kB/s eta 0:00:10
#    -------- ------------------------------- 1.6/7.0 MB 616.8 kB/s eta 0:00:09
#    -------- ------------------------------- 1.6/7.0 MB 616.8 kB/s eta 0:00:09
#    ---------- ----------------------------- 1.8/7.0 MB 617.5 kB/s eta 0:00:09
#    ---------- ----------------------------- 1.8/7.0 MB 617.5 kB/s eta 0:00:09
#    ----------- ---------------------------- 2.1/7.0 MB 618.1 kB/s eta 0:00:08
#    ----------- ---------------------------- 2.1/7.0 MB 618.1 kB/s eta 0:00:08
#    ------------- -------------------------- 2.4/7.0 MB 618.4 kB/s eta 0:00:08
#    ------------- -------------------------- 2.4/7.0 MB 618.4 kB/s eta 0:00:08
#    -------------- ------------------------- 2.6/7.0 MB 618.9 kB/s eta 0:00:08
#    -------------- ------------------------- 2.6/7.0 MB 618.9 kB/s eta 0:00:08
#    ---------------- ----------------------- 2.9/7.0 MB 619.1 kB/s eta 0:00:07
#    ---------------- ----------------------- 2.9/7.0 MB 619.1 kB/s eta 0:00:07
#    ----------------- ---------------------- 3.1/7.0 MB 619.3 kB/s eta 0:00:07
#    ----------------- ---------------------- 3.1/7.0 MB 619.3 kB/s eta 0:00:07
#    ------------------- -------------------- 3.4/7.0 MB 619.5 kB/s eta 0:00:06
#    ------------------- -------------------- 3.4/7.0 MB 619.5 kB/s eta 0:00:06
#    -------------------- ------------------- 3.7/7.0 MB 617.8 kB/s eta 0:00:06
#    -------------------- ------------------- 3.7/7.0 MB 617.8 kB/s eta 0:00:06
#    -------------------- ------------------- 3.7/7.0 MB 617.8 kB/s eta 0:00:06
#    ---------------------- ----------------- 3.9/7.0 MB 619.7 kB/s eta 0:00:06
#    ---------------------- ----------------- 3.9/7.0 MB 619.7 kB/s eta 0:00:06
#    ----------------------- ---------------- 4.2/7.0 MB 619.8 kB/s eta 0:00:05
#    ----------------------- ---------------- 4.2/7.0 MB 619.8 kB/s eta 0:00:05
#    ------------------------- -------------- 4.5/7.0 MB 619.9 kB/s eta 0:00:05
#    ------------------------- -------------- 4.5/7.0 MB 619.9 kB/s eta 0:00:05
#    -------------------------- ------------- 4.7/7.0 MB 620.1 kB/s eta 0:00:04
#    -------------------------- ------------- 4.7/7.0 MB 620.1 kB/s eta 0:00:04
#    ---------------------------- ----------- 5.0/7.0 MB 618.8 kB/s eta 0:00:04
#    ---------------------------- ----------- 5.0/7.0 MB 618.8 kB/s eta 0:00:04
#    ----------------------------- ---------- 5.2/7.0 MB 619.0 kB/s eta 0:00:03
#    ----------------------------- ---------- 5.2/7.0 MB 619.0 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 619.1 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 619.1 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 619.1 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 619.1 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 619.1 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 619.1 kB/s eta 0:00:03
#    ----------------------------------- ---- 6.3/7.0 MB 612.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 6.3/7.0 MB 612.5 kB/s eta 0:00:02
#    ------------------------------------- -- 6.6/7.0 MB 620.4 kB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 646.8 kB/s eta 0:00:00
# Downloading google_auth-2.49.0-py3-none-any.whl (240 kB)
# Installing collected packages: pillow, google-auth, google-genai
#   Attempting uninstall: pillow
#     Found existing installation: pillow 10.3.0
#     Uninstalling pillow-10.3.0:
#       Successfully uninstalled pillow-10.3.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.33.0
#     Uninstalling google-auth-2.33.0:
#       Successfully uninstalled google-auth-2.33.0
# Successfully installed google-auth-2.49.0 google-genai-1.66.0 pillow-10.4.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-firestore 2.17.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.29.5 which is incompatible.
# langchain-google-genai 2.1.10 requires google-ai-generativelanguage<0.7.0,>=0.6.18, but you have google-ai-generativelanguage 0.6.15 which is incompatible.
# streamlit 1.41.1 requires pillow<12,>=7.1.0, but you have pillow 12.1.1 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install requests python-dotenv pillow
# Out:
# Requirement already satisfied: requests in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (1.1.1)
# Requirement already satisfied: pillow in c:\users\prachi shedge\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prachi shedge\appdata\roaming\python\python312\site-packages (from requests) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import os
from dotenv import load_dotenv
from PIL import Image
from io import BytesIO

# Load API key
load_dotenv()
API_TOKEN = os.getenv("HF_TOKEN")

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

API_URL = "https://router.huggingface.co/hf-inference/models/stabilityai/stable-diffusion-xl-base-1.0"

payload = {
    "inputs": "beautiful modern engineering college campus in India, ultra realistic, 4k"
}

response = requests.post(API_URL, headers=headers, json=payload)

# Debug: print status
print("Status Code:", response.status_code)

# Check if response is JSON (error message)
content_type = response.headers.get("content-type", "")

if "application/json" in content_type:
    print("API returned an error:")
    print(response.json())
else:
    image = Image.open(BytesIO(response.content))
    image.save("generated_image.png")
    print("✅ Image saved as generated_image.png")
# Out:
# Status Code: 200
# ✅ Image saved as generated_image.png
